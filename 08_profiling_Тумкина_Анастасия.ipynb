# %% [markdown]
# ## Оптимизация выполнения кода, векторизация, Numba

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 3: Оптимизация выполнения кода, векторизация, Numba
# * IPython Cookbook, Second Edition (2018), глава 4
# * https://numba.pydata.org/numba-doc/latest/user/5minguide.html

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Сгенерируйте массив `A` из `N=1млн` случайных целых чисел на отрезке от 0 до 1000. Пусть `B[i] = A[i] + 100`. Посчитайте среднее значение массива `B`.

# %%
import random
import string

# %%
from numba import njit

# %%
@njit
def f1():
  a = []
  for i in range(1000000):
    a.append(random.randint(0,1001))
  return a

# %%
@njit
def f2():
  b = []
  sum_b = 0
  a = f1()
  for i in a:
    b.append(int(i+100))
    sum_b += i+100
  return sum_b/len(b)

# %%
f2()
# Out:
# 600.142479

# %% [markdown]
# 2. Создайте таблицу 2млн строк и с 4 столбцами, заполненными случайными числами. Добавьте столбец `key`, которые содержит элементы из множества английских букв. Выберите из таблицы подмножество строк, для которых в столбце `key` указаны первые 5 английских букв.

# %%
s1 = pd.DataFrame(np.random.randint ( 0 , 1000 ,size=( 2000000 , 4 )), columns=list('1234'))
s1['key'] = [random.choice('abcdefghijklmnopqrstuvwxyz') for i in range(2000000)]
s1
# Out:
#            1    2    3    4 key
# 0        887  818  872  776   i
# 1        824   55  680  352   u
# 2        327   98  604   37   r
# 3        121  340  387  565   l
# 4        415   34  997  683   b
# ...      ...  ...  ...  ...  ..
# 1999995  594  101   14  951   u
# 1999996  693  873  701  250   y
# 1999997  203  420  543  109   v
# 1999998  474  785  990  251   q
# 1999999  397  496  575  732   k
#
# [2000000 rows x 5 columns]

# %%
s1[s1['key'].isin(list('abcde'))]
# Out:
#            1    2    3    4 key
# 4        415   34  997  683   b
# 23       918   24  632  522   c
# 28       817  424  930  303   e
# 48       428  488  645  885   d
# 50       718  292  615  697   d
# ...      ...  ...  ...  ...  ..
# 1999963  777  758  737  641   d
# 1999966  443  635  683   68   c
# 1999980  396  545  731  849   b
# 1999990  298  597  339  796   d
# 1999992  888  790  961  474   e
#
# [383969 rows x 5 columns]

# %% [markdown]
# ## Лабораторная работа 3

# %%
# !pip install line_profiler
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting line_profiler
#   Downloading line_profiler-4.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.9/661.9 kB 31.0 MB/s eta 0:00:00
# Installing collected packages: line_profiler
# Successfully installed line_profiler-4.0.3

# %%
# %load_ext line_profiler

# %%
import numpy as np
import pandas as pd

# %%
recipes = pd.read_csv('/content/recipes_sample.csv', delimiter=',')
reviews = pd.read_csv('/content/reviews_sample.csv', delimiter=',')
recipes['submitted'] = pd.to_datetime(recipes['submitted'])
reviews['date'] = pd.to_datetime(reviews['date'])
recipes.index = np.arange(1, len(recipes)+1)
reviews.index = np.arange(1, len(reviews)+1)
recipes
# Out:
#                                                name      id  minutes  \
# 1             george s at the cove  black bean soup   44123       90
# 2                healthy for them  yogurt popsicles   67664       10
# 3                      i can t believe it s spinach   38798       30
# 4                              italian  gut busters   35173       45
# 5          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29996  zurie s holey rustic olive and cheddar bread  267661       80
# 29997          zwetschgenkuchen  bavarian plum cake  386977      240
# 29998   zwiebelkuchen   southwest german onion cake  103312       75
# 29999                                   zydeco soup  486161       60
# 30000        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 1               35193 2002-10-25      NaN
# 2               91970 2003-07-26      NaN
# 3                1533 2002-08-29      NaN
# 4               22724 2002-07-27      NaN
# 5                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29996          200862 2007-11-25     16.0
# 29997          177443 2009-08-24      NaN
# 29998          161745 2004-11-03      NaN
# 29999          227978 2012-08-29      NaN
# 30000          506822 2008-04-15      9.0
#
#                                              description  n_ingredients
# 1      an original recipe created by chef scott meska...           18.0
# 2      my children and their friends ask for my homem...            NaN
# 3                these were so go, it surprised even me.            8.0
# 4      my sister-in-law made these for us at a family...            NaN
# 5      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29996  this is based on a french recipe but i changed...           10.0
# 29997  this is a traditional fresh plum cake, thought...           11.0
# 29998  this is a traditional late summer early fall s...            NaN
# 29999  this is a delicious soup that i originally fou...            NaN
# 30000  i've heard of the 'cookies by design' company,...           10.0
#
# [30000 rows x 8 columns]

# %%
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id       date  rating  \
# 1           370476       21752      57993 2003-05-01       5
# 2           624300      431813     142201 2007-09-16       5
# 3           187037      400708     252013 2008-01-10       4
# 4           706134  2001852463     404716 2017-12-11       5
# 5           312179       95810     129396 2008-03-14       5
# ...            ...         ...        ...        ...     ...
# 126692     1013457     1270706     335534 2009-05-17       4
# 126693      158736     2282344       8701 2012-06-03       0
# 126694     1059834      689540     222001 2008-04-08       5
# 126695      453285  2000242659     354979 2015-06-02       5
# 126696      691207      463435     415599 2010-09-30       5
#
#                                                    review
# 1       Last week whole sides of frozen salmon fillet ...
# 2       So simple and so tasty!  I used a yellow capsi...
# 3       Very nice breakfast HH, easy to make and yummy...
# 4       These are a favorite for the holidays and so e...
# 5       Excellent soup!  The tomato flavor is just gre...
# ...                                                   ...
# 126692  This recipe was great! I made it last night. I...
# 126693  This recipe is outstanding. I followed the rec...
# 126694  Well, we were not a crowd but it was a fabulou...
# 126695  I have been a steak eater and dedicated BBQ gr...
# 126696  Wonderful and simple to prepare seasoning blen...
#
# [126696 rows x 6 columns]

# %% [markdown]
# 1. В файлах `recipes_sample.csv` и `reviews_sample.csv` (__ЛР 2__) находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца(ов) с индексами. Приведите столбцы к нужным типам.
#
# Реализуйте несколько вариантов функции подсчета среднего значения столбца `rating` из таблицы `reviews` для отзывов, оставленных в 2010 году.
#
# A. С использованием метода `DataFrame.iterrows` исходной таблицы;
#
# Б. С использованием метода `DataFrame.iterrows` таблицы, в которой сохранены только отзывы за 2010 год;
#
# В. С использованием метода `Series.mean`.
#
# Проверьте, что результаты работы всех написанных функций корректны и совпадают. Измерьте выполнения всех написанных функций.

# %%
def rating1():
  sum = 0
  k = 0
  for i in reviews.iterrows():
    if i[1].date.year == 2010:
      k+=1
      sum += i[1].rating
  return sum/k

rating1()
# Out:
# 4.4544402182900615

# %%
[reviews['date'].dt.year == 2010]
def rating2():
  sum = 0
  k = 0
  for i in reviews[reviews['date'].dt.year == 2010].iterrows():
    k+=1
    sum += i[1].rating
  return sum/k

rating2()
# Out:
# 4.4544402182900615

# %%
def rating3():
  return reviews[reviews['date'].dt.year == 2010].rating.mean()

rating3()
# Out:
# 4.4544402182900615

# %%
# %time rating1()
# Out:
# CPU times: user 6.67 s, sys: 26.5 ms, total: 6.7 s
# Wall time: 6.77 s
# 4.4544402182900615

# %%
# %time rating2()
# Out:
# CPU times: user 625 ms, sys: 547 µs, total: 625 ms
# Wall time: 629 ms
# 4.4544402182900615

# %%
# %time rating3()
# Out:
# CPU times: user 23.9 ms, sys: 0 ns, total: 23.9 ms
# Wall time: 27 ms
# 4.4544402182900615

# %% [markdown]
# 2. Какая из созданных функций выполняется медленнее? Что наиболее сильно влияет на скорость выполнения? Для ответа использовать профайлер `line_profiler`. Сохраните результаты работы профайлера в отдельную текстовую ячейку и прокомментируйте результаты его работы.
#
# (*). Сможете ли вы ускорить работу функции 1Б, отказавшись от использования метода `iterrows`, но не используя метод `mean`?

# %%
# %lprun -f rating1 rating1()

# %% [markdown]
# Timer unit: 1e-09 s
#
# Total time: 12.6855 s
# File: <ipython-input-23-ba9a3576295e>
# Function: rating1 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def rating1():
#      2         1       1088.0   1088.0      0.0    sum = 0
#      3         1        288.0    288.0      0.0    k = 0
#      4    126696 10178755600.0  80340.0     80.2    for i in reviews.iterrows():
#      5    114602 2304775629.0  20111.1     18.2      if i[1].date.year == 2010:
#      6     12094    5574461.0    460.9      0.0        k+=1
#      7     12094  196395178.0  16239.1      1.5        sum += i[1].rating
#      8         1        738.0    738.0      0.0    return sum/k

# %%
# %lprun -f rating2 rating2()

# %% [markdown]
# Timer unit: 1e-09 s
#
# Total time: 1.13153 s
# File: <ipython-input-24-d945731129d9>
# Function: rating2 at line 2
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2                                           def rating2():
#      3         1       1473.0   1473.0      0.0    sum = 0
#      4         1        308.0    308.0      0.0    k = 0
#      5     12094  902090302.0  74589.9     79.7    for i in reviews[reviews['date'].dt.year == 2010].iterrows():
#      6     12094    4805438.0    397.3      0.4      k+=1
#      7     12094  224628349.0  18573.5     19.9      sum += i[1].rating
#      8         1       2144.0   2144.0      0.0    return sum/k

# %%
# %lprun -f rating3 rating3()

# %% [markdown]
# Timer unit: 1e-09 s
#
# Total time: 0.0247684 s
# File: <ipython-input-28-c1d5fa814c6c>
# Function: rating3 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def rating3():
#      2         1   24768430.0 24768430.0    100.0    return reviews[reviews['date'].dt.year == 2010].rating.mean()

# %% [markdown]
# Таким образом, третья функция (rating3) работает намного быстрее двух других, а из фукций rating1 и rating2 оптимальнее использовать rating2

# %% [markdown]
# 3. Вам предлагается воспользоваться функцией, которая собирает статистику о том, сколько отзывов содержат то или иное слово. Измерьте время выполнения этой функции. Сможете ли вы найти узкие места в коде, используя профайлер? Выпишите (словами), что в имеющемся коде реализовано неоптимально. Оптимизируйте функцию и добейтесь значительного (как минимум, на один порядок) прироста в скорости выполнения.

# %%
def get_word_reviews_count(df):
    word_reviews = {}
    for _, row in df.dropna(subset=['review']).iterrows():
        recipe_id, review = row['recipe_id'], row['review']
        words = review.split(' ')
        for word in words:
            if word not in word_reviews:
                word_reviews[word] = []
            word_reviews[word].append(recipe_id)
    
    word_reviews_count = {}
    for _, row in df.dropna(subset=['review']).iterrows():
        review = row['review']
        words = review.split(' ')
        for word in words:
            word_reviews_count[word] = len(word_reviews[word])
    return word_reviews_count

# %%
# %time get_word_reviews_count(reviews)
# Out:
# CPU times: user 21.1 s, sys: 130 ms, total: 21.3 s
# Wall time: 21.8 s
# {'Last': 94,
#  'week': 804,
#  'whole': 5628,
#  'sides': 312,
#  'of': 109029,
#  'frozen': 2647,
#  'salmon': 729,
#  'fillet': 60,
#  'was': 88781,
#  'on': 34583,
#  'sale': 149,
#  'in': 61539,
#  'my': 44144,
#  'local': 561,
#  'supermarket,': 10,
#  'so': 46090,
#  'I': 285147,
#  'bought': 1369,
#  'tons': 161,
#  '(okay,': 5,
#  'only': 13965,
#  '3,': 48,
#  'but': 42513,
#  'total': 381,
#  'weight': 160,
#  'over': 9065,
#  '10': 2303,
#  'pounds).': 2,
#  '': 214145,
#  'This': 39448,
#  'recipe': 41098,
#  'is': 55075,
#  'perfect': 4398,
#  'for': 121224,
#  'fillet,': 14,
#  'even': 7878,
#  'though': 2314,
#  'it': 111175,
#  'calls': 520,
#  'steaks.': 93,
#  'cut': 6688,
#  'up': 13585,
#  'the': 266050,
#  'into': 7031,
#  'individual': 314,
#  'portions': 156,
#  'and': 217849,
#  'followed': 4859,
#  'instructions': 731,
#  'exactly.': 571,
#  "I'm": 7145,
#  'one': 15086,
#  'those': 2287,
#  'food': 2413,
#  'combining': 74,
#  'diets,': 5,
#  'left': 4690,
#  'out': 23644,
#  'white': 3425,
#  'wine': 1256,
#  'added': 21710,
#  'just': 24944,
#  'a': 166136,
#  'dash': 532,
#  'vinegar': 1272,
#  'instead': 10395,
#  '(just': 273,
#  'little': 16319,
#  'bit,': 316,
#  'not': 22907,
#  'enough': 4440,
#  'to': 131471,
#  'change': 4146,
#  'taste': 8026,
#  'dish).': 20,
#  'Super': 840,
#  'yummy,': 366,
#  'leftovers': 1497,
#  'lunch': 1593,
#  'today': 1034,
#  '(lucky': 3,
#  'me)!': 5,
#  'So': 4319,
#  'simple': 3947,
#  'tasty!': 994,
#  'used': 44849,
#  'yellow': 782,
#  'capsicum': 45,
#  'place': 2012,
#  'green': 4470,
#  'because': 11390,
#  "that's": 1563,
#  'what': 7462,
#  'had': 26362,
#  'hand.': 1416,
#  'came': 5263,
#  'together': 3268,
#  'fast.': 178,
#  'Perfect': 755,
#  'meal': 1891,
#  'if': 7326,
#  'you': 24475,
#  "don't": 6183,
#  'have': 35190,
#  'lot': 3186,
#  'time.': 4010,
#  'Easy,': 288,
#  'healthy': 1282,
#  'tasty.': 1986,
#  'Thanks': 26556,
#  'Stardustannie!': 4,
#  'Made': 12801,
#  'PAC': 1488,
#  'Fall': 737,
#  '2007.': 85,
#  'Very': 8691,
#  'nice': 8168,
#  'breakfast': 1398,
#  'HH,': 1,
#  'easy': 17222,
#  'make': 32124,
#  'yummy': 2111,
#  'with': 58374,
#  'fresh': 7670,
#  'hot': 3578,
#  'coffe.': 2,
#  'Instead': 860,
#  'toast': 449,
#  'served': 6449,
#  '#97694': 1,
#  'by': 6592,
#  'Paula': 121,
#  'G': 13,
#  'that': 36984,
#  'made': 38087,
#  'earlier': 167,
#  'turned': 6368,
#  'great.': 3686,
#  'will': 23985,
#  'be': 25032,
#  'regular': 2988,
#  'our': 6879,
#  'house': 1246,
#  '-': 12000,
#  'DH': 3796,
#  'loved': 13755,
#  'them.': 3663,
#  'These': 8371,
#  'are': 15518,
#  'favorite': 2587,
#  'holidays': 123,
#  'children': 356,
#  'We': 12585,
#  'also': 14466,
#  'use': 16905,
#  'Rolo': 6,
#  'candies': 59,
#  'kisses.': 14,
#  'Excellent': 1550,
#  'soup!': 456,
#  'The': 25720,
#  'tomato': 2136,
#  'flavor': 7690,
#  'this': 87057,
#  'freezer': 874,
#  'tag': 808,
#  'soup': 4437,
#  'froze': 645,
#  'beautifully.': 305,
#  'prepared': 935,
#  'as': 35493,
#  'directed': 720,
#  'then': 8440,
#  'allowed': 225,
#  'cool': 953,
#  'container.': 46,
#  'thawed': 211,
#  'fridge': 922,
#  'reheated': 222,
#  'stovetop.': 38,
#  'Worked': 251,
#  'perfectly!': 158,
#  'forgot': 1290,
#  'add': 12987,
#  'skim': 409,
#  'milk': 3759,
#  'still': 6693,
#  'tasted': 4119,
#  'pretty': 3499,
#  'good!': 3887,
#  'Dancer!': 17,
#  'dinner': 3882,
#  'excellent,': 186,
#  'finally': 513,
#  'found': 5067,
#  'tuna': 488,
#  'casserole': 798,
#  'we': 12841,
#  'enjoy,': 11,
#  'thanks.': 123,
#  'When': 1630,
#  'snapped': 9,
#  'picture,': 61,
#  'review': 1142,
#  'recipe.': 14337,
#  'toasted': 775,
#  'pecans': 624,
#  'dish,': 801,
#  'at': 15362,
#  'party': 1243,
#  'Prime': 23,
#  'Rib.': 4,
#  'Ten': 16,
#  'stars': 2070,
#  'Lennie': 29,
#  '!!': 334,
#  'good': 16106,
#  'combination': 1801,
#  'flavors': 2212,
#  'reduce': 910,
#  'rice': 3664,
#  'cilantro': 731,
#  'next': 10082,
#  'time,': 2236,
#  'thanks': 3197,
#  'sharing': 6196,
#  'hon!...Kitten': 9,
#  'Oh': 1335,
#  'Bergy!': 61,
#  'wonderful': 5681,
#  'cakes': 433,
#  'awesome.': 550,
#  'Fast': 83,
#  'put': 8578,
#  'together.': 1445,
#  'get': 6753,
#  'fish': 1128,
#  'where': 971,
#  'live': 435,
#  '(yuck).': 5,
#  'am': 6191,
#  'tired': 147,
#  'trying': 1847,
#  'new': 2765,
#  'recipes': 2819,
#  'help': 761,
#  'lack': 174,
#  'quality.': 62,
#  'But': 2588,
#  'recipe,': 5129,
#  'problem.': 194,
#  'did': 17358,
#  '3': 4472,
#  'cloves': 897,
#  'garlic,': 1029,
#  'seasoned': 776,
#  'bread': 5904,
#  'crumbs': 801,
#  'Smash': 3,
#  'Seasoning(318441).': 1,
#  'It': 19417,
#  'has': 4861,
#  'no': 5863,
#  'salt!\r\nI': 1,
#  'tartar': 77,
#  'sauce': 11425,
#  'go': 3691,
#  '(56860).\r\nThank': 1,
#  'great': 19166,
#  'recipe!': 8487,
#  'very': 25681,
#  'moist': 2457,
#  'cornbread,': 47,
#  'two': 4466,
#  'days': 723,
#  'later.': 237,
#  'less': 3180,
#  'sugar': 6608,
#  'honey,': 203,
#  'farm': 56,
#  'butter...and': 3,
#  'corn,': 222,
#  'about': 12811,
#  '2': 8237,
#  'ears.': 5,
#  'Served': 1974,
#  'ribs': 1203,
#  'grill,': 124,
#  "I've": 5561,
#  'been': 5786,
#  'making': 11030,
#  'past': 418,
#  'several': 1714,
#  'years.': 460,
#  "It's": 2848,
#  'always': 4167,
#  'extremely': 598,
#  'easy!': 923,
#  'posting!': 2469,
#  'generic': 30,
#  'sweetened': 239,
#  'condensed': 231,
#  'works': 748,
#  'well,': 782,
#  'tastes': 2271,
#  'costs': 17,
#  '(I': 2369,
#  'usually': 1911,
#  'Wal-Mart': 3,
#  'brand).': 9,
#  'Exceptional': 7,
#  'delicious': 5729,
#  'make.': 3027,
#  'really': 19400,
#  'liked': 5537,
#  'weekday': 69,
#  'leftover': 1716,
#  'rice.': 1105,
#  'looking': 3050,
#  'different': 3537,
#  'ways': 353,
#  'ground': 2468,
#  'beef.': 346,
#  'love': 9526,
#  'sandwich!!': 10,
#  'alot': 435,
#  'sooo': 594,
#  'Lite': 22,
#  'brown': 3475,
#  'mustard': 1082,
#  'horse': 4,
#  'relish': 159,
#  'some': 20753,
#  'olives': 582,
#  "on's.": 1,
#  'Next': 3485,
#  'time': 17502,
#  'balsamic': 482,
#  'dressing...it': 2,
#  'mind.': 76,
#  ':)': 5164,
#  'cbreezie': 1,
#  'make,': 1286,
#  'affordable': 26,
#  'addicting.': 29,
#  'Our': 363,
#  'household': 66,
#  'it.': 11935,
#  'Blessings': 7,
#  'chef': 292,
#  'sharing.': 2159,
#  'never': 4979,
#  'apple': 1442,
#  'orange': 1633,
#  'juice': 2765,
#  'makes': 3300,
#  'all': 15499,
#  'difference': 673,
#  'texture': 2318,
#  'bread.': 1207,
#  'wonderful!!\r\nThank': 2,
#  'You': 2286,
#  'were': 20716,
#  'delicious!': 3344,
#  'grated': 943,
#  'bit': 9946,
#  'cheddar': 1380,
#  'cheese': 8218,
#  'top': 4343,
#  '5': 4283,
#  'minutes': 5013,
#  'before': 6918,
#  'they': 16863,
#  'done,': 239,
#  'seasoning': 2026,
#  'perfect.': 2023,
#  'best': 4551,
#  'pizza': 955,
#  'dough': 2740,
#  'made!': 190,
#  'Other': 574,
#  'tried': 4438,
#  'machine': 480,
#  'way': 6708,
#  'too': 10530,
#  'sticky.': 81,
#  'Leaving': 11,
#  'msg': 19,
#  'fine.': 946,
#  'divide': 60,
#  'half,': 411,
#  'knead': 90,
#  'floured': 83,
#  'surface': 69,
#  'few': 4897,
#  'times,': 290,
#  'stretch': 74,
#  'cirle.': 1,
#  'like': 20171,
#  'bake': 1806,
#  'cast-iron': 19,
#  'skillet-': 1,
#  'brush': 161,
#  'pan': 3626,
#  'olive': 2058,
#  'oil': 3790,
#  'sprinkle': 635,
#  'corn': 2175,
#  'meal.': 1607,
#  'crust': 1662,
#  '7': 705,
#  '10-15': 75,
#  'lowest': 28,
#  'rack': 265,
#  'oven.': 1053,
#  'saw': 745,
#  'Giada': 8,
#  'Today': 106,
#  'show': 174,
#  'last': 4502,
#  'month': 270,
#  'wanted': 2687,
#  'compare': 104,
#  'family': 7201,
#  'being': 1855,
#  'Marsala': 25,
#  'dry': 2150,
#  'red,': 78,
#  'chicken/turkey': 3,
#  'sausage,': 225,
#  'cutting': 557,
#  'sausages': 113,
#  'finishing': 127,
#  'cooking': 4203,
#  'stove': 565,
#  'My': 14347,
#  'traditionally': 25,
#  'serves': 152,
#  'sausage': 1116,
#  'peppers': 1410,
#  'polenta...this': 1,
#  'compared': 122,
#  'well': 5166,
#  'probably': 2651,
#  'calories': 377,
#  'heats': 11,
#  'kitchen': 520,
#  'summertime!': 2,
#  'meatloaf,': 47,
#  'took': 3830,
#  'reviewers': 587,
#  'suggestion': 524,
#  'another': 4777,
#  'crock': 1034,
#  'pot': 1977,
#  'meatloaf': 395,
#  '(#99616)': 1,
#  'it,': 3813,
#  'sauce,': 1640,
#  'meatloaf.': 109,
#  'sweet': 4938,
#  'tangy': 290,
#  'wonder': 263,
#  'addition.': 273,
#  'again.': 7348,
#  'deliciously': 87,
#  'simple.': 292,
#  'can': 9513,
#  'literally': 148,
#  'thrown': 103,
#  'soups': 203,
#  'i': 7770,
#  'ever': 3856,
#  'had.': 886,
#  'uncomplicated': 6,
#  'taste.': 2042,
#  ',': 715,
#  'from': 12802,
#  'appealed': 20,
#  'me': 7274,
#  'simplicity': 162,
#  'quick': 4068,
#  'could': 6285,
#  'made.': 705,
#  'both': 2697,
#  'flavor.': 3912,
#  'anything': 1423,
#  'see': 2244,
#  'can;': 1,
#  'more': 16840,
#  'substance': 14,
#  'nothing': 718,
#  '(thankfully)': 3,
#  'rustic': 43,
#  'roasted': 1256,
#  'balance': 423,
#  'other': 7016,
#  'ingredients.': 1084,
#  'paul': 2,
#  'newman': 1,
#  'marinara': 109,
#  '1/3': 778,
#  'cup': 7164,
#  'let': 2910,
#  'simmer': 398,
#  'out.': 1223,
#  'would': 16597,
#  'definitly': 60,
#  'much': 12363,
#  'plus': 779,
#  'tea!': 45,
#  'aroma': 300,
#  'tea': 535,
#  'steeping': 10,
#  'five': 663,
#  'minutes,': 843,
#  'wonderful!': 1109,
#  'large': 2093,
#  'glass': 571,
#  'ice': 1500,
#  'enjoyed!': 69,
#  'Good': 1325,
#  'marinade.': 218,
#  'Jack': 169,
#  'Daniels': 23,
#  'exactly': 3583,
#  'except': 2033,
#  "didn't": 14046,
#  'marinate': 353,
#  'quite': 3819,
#  'long.': 221,
#  'hours.': 867,
#  'grilled': 1248,
#  'counter': 137,
#  'grill': 812,
#  'everyone': 2528,
#  'enjoyed': 6746,
#  'Even': 1366,
#  'DH,': 122,
#  'who': 3066,
#  "doesn't": 1810,
#  'beef': 2513,
#  'dressed': 64,
#  'up,': 513,
#  'said': 3122,
#  'Almost': 108,
#  'teriyaki': 96,
#  'baked': 4137,
#  'potato': 1754,
#  'asparagus.': 143,
#  'posting.': 2221,
#  'Fantastic': 361,
#  'earning': 2,
#  'raves': 111,
#  'table.': 201,
#  'Thanks,': 1331,
#  'homegirl!': 5,
#  'comforting.': 50,
#  'low-sodium,': 1,
#  'low-fat': 296,
#  'chicken': 11332,
#  'stock.': 166,
#  'butter.': 945,
#  'dried': 2248,
#  'parsley.': 200,
#  'do': 6861,
#  'than': 10333,
#  'an': 10553,
#  'hour,': 174,
#  'Me': 65,
#  'course.': 92,
#  'Breezermom': 3,
#  'Market': 162,
#  'game': 469,
#  'Easy': 1911,
#  'good.': 7001,
#  'Will': 3432,
#  'again': 7921,
#  'kids': 3123,
#  'weekend,': 54,
#  'your': 6415,
#  'cookies': 1935,
#  'already': 1564,
#  '(your': 4,
#  'Triple': 17,
#  'Chocolates).': 1,
#  "We're": 115,
#  'addicted': 63,
#  'jam': 430,
#  '--': 1634,
#  "it's": 4846,
#  'tend': 205,
#  'vinegar-phobic': 1,
#  'half;': 9,
#  'adore': 101,
#  'black': 1609,
#  'pepper,': 929,
#  'increase': 507,
#  'half.': 567,
#  'Also,': 1561,
#  'once': 1547,
#  'strawberries': 539,
#  'cook': 4212,
#  'down,': 140,
#  'masher': 37,
#  'break': 188,
#  'them': 19689,
#  'consistency.': 287,
#  'pepper': 4401,
#  'kick': 525,
#  'fun,': 59,
#  'English': 151,
#  'muffins,': 161,
#  'peanut': 1356,
#  'butter': 5572,
#  '&': 9664,
#  'jelly': 298,
#  'sandwiches': 473,
#  '(made': 53,
#  'wheat': 1778,
#  'bread.)': 3,
#  'wish': 831,
#  'canning': 142,
#  'store': 1248,
#  'shelf': 48,
#  'it!': 4313,
#  'started': 876,
#  'yesterday': 436,
#  'keep': 2162,
#  'up.': 1429,
#  'back': 3474,
#  'coffee': 976,
#  'figured': 251,
#  'might': 2834,
#  'along': 1572,
#  'benefits.': 12,
#  'OK,': 118,
#  'NEVER': 136,
#  'buy': 1174,
#  'jarred': 130,
#  'terrific!': 129,
#  'early': 259,
#  'day,': 352,
#  'later!': 31,
#  'pizza,': 66,
#  'freezer.': 284,
#  'cant': 183,
#  'wait.': 63,
#  'hint': 419,
#  'spice': 1363,
#  'red': 4424,
#  'omitted': 1607,
#  'flakes': 754,
#  'small': 3035,
#  'delicious.': 3734,
#  'again,': 2053,
#  'tenderness': 27,
#  'rub': 356,
#  'right.': 542,
#  'cold,': 101,
#  'yogurt': 961,
#  'whipped': 834,
#  'in,': 275,
#  'or': 12020,
#  'top.': 1375,
#  'cumin,': 184,
#  'curry,': 57,
#  'cinnamon': 2082,
#  'try': 8937,
#  'Chinese': 203,
#  '5.': 153,
#  "can't": 3022,
#  'resist': 98,
#  'splash': 304,
#  'too!': 1288,
#  '"bake"': 5,
#  'squash': 549,
#  'microwave': 830,
#  '8': 1712,
#  'minute': 545,
#  'blasts': 1,
#  'peel': 343,
#  'when': 9491,
#  'cool,': 89,
#  'freeze': 792,
#  'flesh.': 7,
#  'Carrots': 32,
#  'eaten': 749,
#  'right': 3563,
#  'highly': 529,
#  'recommend': 1542,
#  'these': 14418,
#  'delicious,': 1064,
#  'yet': 1087,
#  'treats!': 27,
#  'plastic': 293,
#  'popsicle': 9,
#  'molds': 10,
#  'store.': 239,
#  'halved': 1284,
#  '16': 340,
#  'popsicles.': 5,
#  'They': 5927,
#  'adults': 195,
#  'gone': 759,
#  'crazy': 379,
#  'eating': 2032,
#  'And': 2587,
#  'since': 4612,
#  "they're": 440,
#  'them!': 817,
#  'Barb': 33,
#  'become': 734,
#  'favorite!': 215,
#  'good,': 3031,
#  'modifications': 131,
#  '(and': 1001,
#  'laziness).': 1,
#  'semi': 81,
#  'breasts,': 185,
#  'browned': 670,
#  'them,': 1125,
#  'stock': 853,
#  'rest': 1884,
#  'through': 1258,
#  'simmer.': 28,
#  'omit': 595,
#  'avoid': 195,
#  'sugary-ness': 1,
#  'commented': 144,
#  'PERFECT.': 35,
#  'As': 1547,
#  'couscous': 179,
#  'anything,': 94,
#  'cold': 1240,
#  'broth': 1953,
#  'soak': 317,
#  'wait': 2103,
#  'breasts': 981,
#  'cook.': 325,
#  'margarine': 312,
#  'garlic-buttery': 1,
#  'certainly': 920,
#  'disappoint).': 1,
#  '#289161.': 1,
#  'Miraklegirl!': 4,
#  'fantastic!': 779,
#  'soft': 1275,
#  'chewy': 397,
#  'loveddd': 1,
#  'friends.': 197,
#  'chopped': 3127,
#  'mars': 2,
#  'bar': 219,
#  'chocolate': 4609,
#  'chips': 1692,
#  'worked': 3075,
#  'charm': 25,
#  'definitely': 6267,
#  'THANKS': 93,
#  'Christmas': 1344,
#  'party!': 71,
#  'Thank': 9735,
#  'treat!': 343,
#  'dressing': 2160,
#  'lot.': 369,
#  'sesame': 650,
#  'seeds': 805,
#  'lamb': 384,
#  'marinaded': 64,
#  'spices.': 376,
#  'posting': 4351,
#  'simply': 738,
#  'WONDERFUL!': 102,
#  'any': 6231,
#  'salt,': 1020,
#  'substitution': 119,
#  "necessity..didn't": 1,
#  'hash': 168,
#  'browns,': 19,
#  'potatoes.': 996,
#  'About': 72,
#  'half': 7891,
#  'peeked': 5,
#  'browning': 302,
#  'bottom': 1067,
#  'potatoes': 3793,
#  "weren't": 511,
#  'cooking.': 721,
#  'needed': 2633,
#  'water.': 897,
#  'DUH!': 1,
#  'remember': 574,
#  'how': 5263,
#  'added,': 81,
#  "I'll": 5414,
#  'redo': 7,
#  'browns': 104,
#  'die': 409,
#  'for....': 2,
#  'truly!': 1,
#  'good..': 25,
#  'it..': 61,
#  'give': 3294,
#  '3.5': 93,
#  'stars.': 688,
#  'okay': 242,
#  'again.<br/><br/>I': 2,
#  'drumsticks': 59,
#  'wings': 425,
#  'grocery': 438,
#  'low': 2407,
#  'sodium': 453,
#  'soy': 1154,
#  'sauce.': 3014,
#  'forget': 241,
#  'marinade': 1074,
#  'chicken.': 1191,
#  'know': 3493,
#  'affected': 64,
#  'thicker.': 86,
#  'barbecue': 199,
#  'move': 69,
#  'fluid.': 6,
#  'thicken': 702,
#  'starch': 190,
#  'flour.': 770,
#  'stated': 531,
#  ':-)': 651,
#  'breakfast!': 170,
#  'mom': 793,
#  'Northern': 39,
#  'Ireland': 14,
#  'introduced': 38,
#  'Marmite': 9,
#  'age': 38,
#  'rye': 150,
#  'marmite': 8,
#  'dip': 1014,
#  'eggs.': 408,
#  'you!': 1483,
#  "Paula's": 14,
#  'Peach': 20,
#  'Dump': 9,
#  'Cake': 198,
#  '#125391': 1,
#  '(only': 110,
#  '4)': 28,
#  'forward': 785,
#  'her': 1377,
#  'call': 572,
#  'future.': 285,
#  'hand': 1526,
#  'dessert': 1009,
#  "'fix'": 2,
#  'table': 454,
#  'short': 442,
#  'notice.': 16,
#  'Wow!': 684,
#  'What': 2588,
#  'amazing': 894,
#  'stuff!': 202,
#  'Hokey': 4,
#  'Pokey': 5,
#  'ice-cream,': 6,
#  'this.\nI': 3,
#  'shocked': 59,
#  'complete': 234,
#  'colour': 105,
#  'after': 5685,
#  'stirring': 211,
#  'baking': 3090,
#  'soda': 304,
#  'through.': 295,
#  'quick.\nI': 1,
#  'burned': 183,
#  'ours': 252,
#  'difficult': 371,
#  'spread': 1079,
#  'flat': 296,
#  'pan,': 648,
#  'first': 6060,
#  'go.\nNext': 1,
#  "what's": 98,
#  'come!': 37,
#  'manual': 7,
#  'method': 625,
#  'directions': 1514,
#  'follow': 830,
#  'produced': 149,
#  'results.': 577,
#  'light': 2557,
#  "za'atar": 11,
#  'topping.': 466,
#  'keeper!': 1322,
#  'Best': 634,
#  '2011': 181,
#  'event,': 33,
#  'recommended': 325,
#  'awalde': 7,
#  'sorry.': 81,
#  "wasn't": 2828,
#  'stretch.': 6,
#  'There': 1134,
#  'something': 3789,
#  'missing': 501,
#  'turn': 1174,
#  'amazing.': 614,
#  'turmeric': 68,
#  'strange': 126,
#  'color': 571,
#  'unappealing.': 7,
#  'smelled': 705,
#  'carne': 7,
#  'asada': 5,
#  'maybe': 2146,
#  'expecting.': 53,
#  'cooked': 6317,
#  'delightful': 259,
#  'while': 3129,
#  'grilling': 225,
#  'meet': 53,
#  'expectations': 42,
#  'served.': 66,
#  'watching': 228,
#  'think': 10740,
#  'tweak': 194,
#  'sure': 5334,
#  'is.': 636,
#  'Did': 453,
#  'Bergy!!': 10,
#  'microwaved': 176,
#  'spuds,': 5,
#  'onions,': 735,
#  'later': 496,
#  'night.': 694,
#  'onion': 3951,
#  'each': 2204,
#  'their': 1558,
#  'flavours': 430,
#  'come': 1545,
#  'distinctly.\r\nGood': 1,
#  'veggie': 655,
#  'dish.': 2670,
#  'Lovely!': 31,
#  'beautiful': 760,
#  'Thanksgiving': 638,
#  'morning.': 386,
#  'With': 666,
#  'link': 42,
#  'sliced': 2056,
#  'fruit': 1048,
#  'enjoy': 1321,
#  'visiting': 112,
#  'grands': 5,
#  'breakfast.': 477,
#  'Kittencal.': 81,
#  'teach': 25,
#  'high': 1257,
#  'school': 333,
#  'foods': 180,
#  'class': 97,
#  'studying': 8,
#  'legumes.': 2,
#  'topping': 1361,
#  'sour': 2563,
#  'cream,': 790,
#  'cheese,': 1367,
#  'Tobasco': 19,
#  'tortilla': 507,
#  'chips.': 630,
#  'While': 418,
#  'making,': 33,
#  'students': 37,
#  'look': 1527,
#  'Not': 1846,
#  'single': 364,
#  'student': 38,
#  '25': 458,
#  'disliked': 19,
#  'students.': 8,
#  'starting': 247,
#  'hour': 1180,
#  'period': 41,
#  'reheating': 45,
#  'day.': 1214,
#  'Many': 181,
#  'requested': 363,
#  'second': 1653,
#  'copy': 147,
#  'take': 2301,
#  'home!': 96,
#  'Great': 5595,
#  'job!': 33,
#  'definately': 1072,
#  'lemon': 3806,
#  'zest': 575,
#  'devine': 17,
#  'reheat': 135,
#  'oven': 3332,
#  ...}

# %%
# %lprun -f get_word_reviews_count get_word_reviews_count(reviews)

# %% [markdown]
# Timer unit: 1e-09 s
#
# Total time: 45.7761 s
# File: <ipython-input-43-b1bc049bcd0c>
# Function: get_word_reviews_count at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def get_word_reviews_count(df):
#      2         1       1455.0   1455.0      0.0      word_reviews = {}
#      3    126679 11860438451.0  93625.9     25.9      for _, row in df.dropna(subset=['review']).iterrows():
#      4    126679 2750962003.0  21716.0      6.0          recipe_id, review = row['recipe_id'], row['review']
#      5    126679  646036892.0   5099.8      1.4          words = review.split(' ')
#      6   6792010 1769033076.0    260.5      3.9          for word in words:
#      7   6617066 3208417847.0    484.9      7.0              if word not in word_reviews:
#      8    174944   96797178.0    553.3      0.2                  word_reviews[word] = []
#      9   6792010 4357227117.0    641.5      9.5              word_reviews[word].append(recipe_id)
#     10
#     11         1        518.0    518.0      0.0      word_reviews_count = {}
#     12    126679 11098949783.0  87614.8     24.2      for _, row in df.dropna(subset=['review']).iterrows():
#     13    126679 1671608688.0  13195.6      3.7          review = row['review']
#     14    126679  614638740.0   4851.9      1.3          words = review.split(' ')
#     15   6792010 1785656650.0    262.9      3.9          for word in words:
#     16   6792010 5916379966.0    871.1     12.9              word_reviews_count[word] = len(word_reviews[word])
#     17         1        546.0    546.0      0.0      return word_reviews_count

# %% [markdown]
# В данном коде очень неоптимально реализован перебор, так как нам приходится дважды проходить по одним и тем же данным, вместо того, чтобы взять нужную информацию за 1 раз. Поэтому, я предлагаю такой способ решения данного задания:

# %%
def get_word_reviews_count1(df):
  sl = {}
  for i in df.review:
    try:
      words = i.split()
    except:
      continue
    for j in words:
      if j not in sl.keys():
        sl[j] = 1
      else:
        sl[j] +=1
  return sl
get_word_reviews_count1(reviews)
# Out:
# {'Last': 100,
#  'week': 804,
#  'whole': 5630,
#  'sides': 313,
#  'of': 109040,
#  'frozen': 2648,
#  'salmon': 729,
#  'fillet': 60,
#  'was': 88793,
#  'on': 34590,
#  'sale': 149,
#  'in': 61551,
#  'my': 44166,
#  'local': 561,
#  'supermarket,': 10,
#  'so': 46106,
#  'I': 288141,
#  'bought': 1369,
#  'tons': 161,
#  '(okay,': 5,
#  'only': 13967,
#  '3,': 48,
#  'but': 42528,
#  'total': 381,
#  'weight': 160,
#  'over': 9066,
#  '10': 2305,
#  'pounds).': 3,
#  'This': 39937,
#  'recipe': 41128,
#  'is': 55083,
#  'perfect': 4400,
#  'for': 121248,
#  'fillet,': 14,
#  'even': 7881,
#  'though': 2315,
#  'it': 111224,
#  'calls': 520,
#  'steaks.': 96,
#  'cut': 6689,
#  'up': 13585,
#  'the': 266099,
#  'into': 7035,
#  'individual': 314,
#  'portions': 156,
#  'and': 217925,
#  'followed': 4861,
#  'instructions': 731,
#  'exactly.': 578,
#  "I'm": 7227,
#  'one': 15090,
#  'those': 2287,
#  'food': 2416,
#  'combining': 74,
#  'diets,': 5,
#  'left': 4691,
#  'out': 23647,
#  'white': 3426,
#  'wine': 1258,
#  'added': 21723,
#  'just': 24955,
#  'a': 166160,
#  'dash': 532,
#  'vinegar': 1273,
#  'instead': 10397,
#  '(just': 275,
#  'little': 16323,
#  'bit,': 316,
#  'not': 22914,
#  'enough': 4443,
#  'to': 131496,
#  'change': 4147,
#  'taste': 8037,
#  'dish).': 20,
#  'Super': 847,
#  'yummy,': 367,
#  'leftovers': 1498,
#  'lunch': 1594,
#  'today': 1035,
#  '(lucky': 3,
#  'me)!': 5,
#  'So': 4382,
#  'simple': 3952,
#  'tasty!': 1016,
#  'used': 44870,
#  'yellow': 782,
#  'capsicum': 45,
#  'place': 2012,
#  'green': 4472,
#  'because': 11394,
#  "that's": 1564,
#  'what': 7467,
#  'had': 26366,
#  'hand.': 1450,
#  'came': 5263,
#  'together': 3268,
#  'fast.': 181,
#  'Perfect': 764,
#  'meal': 1893,
#  'if': 7333,
#  'you': 24491,
#  "don't": 6185,
#  'have': 35191,
#  'lot': 3187,
#  'time.': 4086,
#  'Easy,': 294,
#  'healthy': 1282,
#  'tasty.': 2019,
#  'Thanks': 27943,
#  'Stardustannie!': 4,
#  'Made': 13273,
#  'PAC': 1488,
#  'Fall': 737,
#  '2007.': 89,
#  'Very': 8812,
#  'nice': 8169,
#  'breakfast': 1399,
#  'HH,': 1,
#  'easy': 17234,
#  'make': 32132,
#  'yummy': 2113,
#  'with': 58387,
#  'fresh': 7673,
#  'hot': 3582,
#  'coffe.': 2,
#  'Instead': 876,
#  'toast': 449,
#  'served': 6450,
#  '#97694': 1,
#  'by': 6596,
#  'Paula': 124,
#  'G': 13,
#  'that': 36991,
#  'made': 38102,
#  'earlier': 167,
#  'turned': 6372,
#  'great.': 3751,
#  'will': 23997,
#  'be': 25033,
#  'regular': 2988,
#  'our': 6879,
#  'house': 1247,
#  '-': 12026,
#  'DH': 3818,
#  'loved': 13758,
#  'them.': 3711,
#  'These': 8459,
#  'are': 15522,
#  'favorite': 2588,
#  'holidays': 123,
#  'children': 356,
#  'We': 12823,
#  'also': 14471,
#  'use': 16908,
#  'Rolo': 6,
#  'candies': 59,
#  'kisses.': 15,
#  'Excellent': 1564,
#  'soup!': 458,
#  'The': 26264,
#  'tomato': 2136,
#  'flavor': 7691,
#  'this': 87098,
#  'freezer': 875,
#  'tag': 808,
#  'soup': 4442,
#  'froze': 645,
#  'beautifully.': 316,
#  'prepared': 935,
#  'as': 35504,
#  'directed': 720,
#  'then': 8443,
#  'allowed': 225,
#  'cool': 953,
#  'container.': 47,
#  'thawed': 211,
#  'fridge': 922,
#  'reheated': 223,
#  'stovetop.': 38,
#  'Worked': 252,
#  'perfectly!': 161,
#  'forgot': 1290,
#  'add': 12993,
#  'skim': 409,
#  'milk': 3766,
#  'still': 6694,
#  'tasted': 4122,
#  'pretty': 3499,
#  'good!': 3934,
#  'Dancer!': 17,
#  'dinner': 3885,
#  'excellent,': 187,
#  'finally': 513,
#  'found': 5068,
#  'tuna': 488,
#  'casserole': 799,
#  'we': 12853,
#  'enjoy,': 11,
#  'thanks.': 130,
#  'When': 1663,
#  'snapped': 9,
#  'picture,': 61,
#  'review': 1143,
#  'recipe.': 14557,
#  'toasted': 775,
#  'pecans': 624,
#  'dish,': 803,
#  'at': 15363,
#  'party': 1244,
#  'Prime': 23,
#  'Rib.': 4,
#  'Ten': 17,
#  'stars': 2079,
#  'Lennie': 31,
#  '!!': 352,
#  'good': 16119,
#  'combination': 1801,
#  'flavors': 2214,
#  'reduce': 910,
#  'rice': 3667,
#  'cilantro': 732,
#  'next': 10083,
#  'time,': 2236,
#  'thanks': 3267,
#  'sharing': 6200,
#  'hon!...Kitten': 9,
#  'Oh': 1360,
#  'Bergy!': 64,
#  'wonderful': 5686,
#  'cakes': 433,
#  'awesome.': 557,
#  'Fast': 84,
#  'put': 8579,
#  'together.': 1467,
#  'get': 6754,
#  'fish': 1130,
#  'where': 971,
#  'live': 435,
#  '(yuck).': 5,
#  'am': 6193,
#  'tired': 147,
#  'trying': 1847,
#  'new': 2765,
#  'recipes': 2819,
#  'help': 762,
#  'lack': 174,
#  'quality.': 62,
#  'But': 2644,
#  'recipe,': 5134,
#  'problem.': 198,
#  'did': 17362,
#  '3': 4487,
#  'cloves': 900,
#  'garlic,': 1030,
#  'seasoned': 776,
#  'bread': 5904,
#  'crumbs': 801,
#  'Smash': 3,
#  'Seasoning(318441).': 1,
#  'It': 19705,
#  'has': 4861,
#  'no': 5865,
#  'salt!': 29,
#  'tartar': 77,
#  'sauce': 11432,
#  'go': 3694,
#  '(56860).': 1,
#  'Thank': 10267,
#  'great': 19179,
#  'recipe!': 8613,
#  'very': 25695,
#  'moist': 2458,
#  'cornbread,': 47,
#  'two': 4466,
#  'days': 723,
#  'later.': 245,
#  'less': 3181,
#  'sugar': 6626,
#  'honey,': 203,
#  'farm': 56,
#  'butter...and': 3,
#  'corn,': 222,
#  'about': 12814,
#  '2': 8277,
#  'ears.': 5,
#  'Served': 2024,
#  'ribs': 1203,
#  'grill,': 124,
#  "I've": 5612,
#  'been': 5787,
#  'making': 11032,
#  'past': 418,
#  'several': 1715,
#  'years.': 466,
#  "It's": 2897,
#  'always': 4171,
#  'extremely': 599,
#  'easy!': 939,
#  'posting!': 2507,
#  'generic': 30,
#  'sweetened': 239,
#  'condensed': 231,
#  'works': 748,
#  'well,': 783,
#  'tastes': 2272,
#  'costs': 17,
#  '(I': 2379,
#  'usually': 1911,
#  'Wal-Mart': 3,
#  'brand).': 9,
#  'Exceptional': 7,
#  'delicious': 5732,
#  'make.': 3070,
#  'really': 19407,
#  'liked': 5539,
#  'weekday': 69,
#  'leftover': 1716,
#  'rice.': 1119,
#  'looking': 3050,
#  'different': 3538,
#  'ways': 353,
#  'ground': 2468,
#  'beef.': 355,
#  'love': 9530,
#  'sandwich!!': 12,
#  'alot': 435,
#  'sooo': 594,
#  'Lite': 22,
#  'brown': 3477,
#  'mustard': 1084,
#  'horse': 4,
#  'relish': 160,
#  'some': 20757,
#  'olives': 583,
#  "on's.": 1,
#  'Next': 3562,
#  'time': 17505,
#  'balsamic': 483,
#  'dressing...it': 2,
#  'mind.': 77,
#  ':)': 5385,
#  'cbreezie': 1,
#  'make,': 1288,
#  'affordable': 26,
#  'addicting.': 30,
#  'Our': 372,
#  'household': 66,
#  'it.': 12186,
#  'Blessings': 7,
#  'chef': 295,
#  'sharing.': 2200,
#  'never': 4979,
#  'apple': 1442,
#  'orange': 1633,
#  'juice': 2768,
#  'makes': 3301,
#  'all': 15505,
#  'difference': 674,
#  'texture': 2318,
#  'bread.': 1218,
#  'wonderful!!': 110,
#  'You': 2333,
#  'were': 20719,
#  'delicious!': 3387,
#  'grated': 944,
#  'bit': 9947,
#  'cheddar': 1382,
#  'cheese': 8220,
#  'top': 4345,
#  '5': 4296,
#  'minutes': 5016,
#  'before': 6922,
#  'they': 16874,
#  'done,': 239,
#  'seasoning': 2026,
#  'perfect.': 2056,
#  'best': 4552,
#  'pizza': 956,
#  'dough': 2740,
#  'made!': 192,
#  'Other': 594,
#  'tried': 4438,
#  'machine': 480,
#  'way': 6710,
#  'too': 10538,
#  'sticky.': 83,
#  'Leaving': 11,
#  'msg': 19,
#  'fine.': 971,
#  'divide': 60,
#  'half,': 411,
#  'knead': 90,
#  'floured': 83,
#  'surface': 69,
#  'few': 4898,
#  'times,': 290,
#  'stretch': 74,
#  'cirle.': 1,
#  'like': 20175,
#  'bake': 1806,
#  'cast-iron': 19,
#  'skillet-': 1,
#  'brush': 161,
#  'pan': 3627,
#  'olive': 2059,
#  'oil': 3796,
#  'sprinkle': 635,
#  'corn': 2176,
#  'meal.': 1639,
#  'crust': 1662,
#  '7': 705,
#  '10-15': 75,
#  'lowest': 28,
#  'rack': 265,
#  'oven.': 1073,
#  'saw': 746,
#  'Giada': 8,
#  'Today': 109,
#  'show': 174,
#  'last': 4502,
#  'month': 271,
#  'wanted': 2689,
#  'compare': 104,
#  'family': 7202,
#  'being': 1855,
#  'Marsala': 25,
#  'dry': 2151,
#  'red,': 78,
#  'chicken/turkey': 3,
#  'sausage,': 225,
#  'cutting': 557,
#  'sausages': 113,
#  'finishing': 127,
#  'cooking': 4205,
#  'stove': 565,
#  'My': 14586,
#  'traditionally': 25,
#  'serves': 152,
#  'sausage': 1117,
#  'peppers': 1411,
#  'polenta...this': 1,
#  'compared': 122,
#  'well': 5171,
#  'probably': 2651,
#  'calories': 377,
#  'heats': 11,
#  'kitchen': 520,
#  'summertime!': 2,
#  'meatloaf,': 47,
#  'took': 3831,
#  'reviewers': 587,
#  'suggestion': 525,
#  'another': 4781,
#  'crock': 1034,
#  'pot': 1978,
#  'meatloaf': 395,
#  '(#99616)': 1,
#  'it,': 3814,
#  'sauce,': 1640,
#  'meatloaf.': 109,
#  'sweet': 4940,
#  'tangy': 290,
#  'wonder': 263,
#  'addition.': 281,
#  'again.': 7485,
#  'deliciously': 87,
#  'simple.': 295,
#  'can': 9516,
#  'literally': 148,
#  'thrown': 103,
#  'soups': 203,
#  'i': 7828,
#  'ever': 3857,
#  'had.': 897,
#  'uncomplicated': 6,
#  'taste.': 2088,
#  ',': 715,
#  'from': 12806,
#  'appealed': 20,
#  'me': 7276,
#  'simplicity': 162,
#  'quick': 4069,
#  'could': 6288,
#  'made.': 711,
#  'both': 2698,
#  'flavor.': 3964,
#  'anything': 1423,
#  'see': 2246,
#  'can;': 1,
#  'more': 16845,
#  'substance': 14,
#  'nothing': 719,
#  '(thankfully)': 3,
#  'rustic': 43,
#  'roasted': 1256,
#  'balance': 423,
#  'other': 7019,
#  'ingredients.': 1100,
#  'paul': 2,
#  'newman': 1,
#  'marinara': 109,
#  '1/3': 780,
#  'cup': 7165,
#  'let': 2910,
#  'simmer': 398,
#  'out.': 1250,
#  'would': 16602,
#  'definitly': 60,
#  'much': 12368,
#  'plus': 779,
#  'tea!': 46,
#  'aroma': 300,
#  'tea': 535,
#  'steeping': 10,
#  'five': 664,
#  'minutes,': 843,
#  'wonderful!': 1125,
#  'large': 2093,
#  'glass': 571,
#  'ice': 1502,
#  'enjoyed!': 71,
#  'Good': 1356,
#  'marinade.': 220,
#  'Jack': 169,
#  'Daniels': 23,
#  'exactly': 3584,
#  'except': 2035,
#  "didn't": 14049,
#  'marinate': 353,
#  'quite': 3821,
#  'long.': 228,
#  'hours.': 885,
#  'grilled': 1248,
#  'counter': 138,
#  'grill': 812,
#  'everyone': 2532,
#  'enjoyed': 6746,
#  'Even': 1386,
#  'DH,': 123,
#  'who': 3069,
#  "doesn't": 1810,
#  'beef': 2514,
#  'dressed': 64,
#  'up,': 513,
#  'said': 3122,
#  'Almost': 108,
#  'teriyaki': 96,
#  'baked': 4138,
#  'potato': 1755,
#  'asparagus.': 144,
#  'posting.': 2316,
#  'Fantastic': 367,
#  'earning': 2,
#  'raves': 111,
#  'table.': 207,
#  'Thanks,': 1423,
#  'homegirl!': 5,
#  'comforting.': 50,
#  'low-sodium,': 1,
#  'low-fat': 296,
#  'chicken': 11333,
#  'stock.': 172,
#  'butter.': 965,
#  'dried': 2248,
#  'parsley.': 205,
#  'do': 6861,
#  'than': 10334,
#  'an': 10558,
#  'hour,': 174,
#  'Me': 68,
#  'course.': 94,
#  'Breezermom': 3,
#  'Market': 162,
#  'game': 469,
#  'Easy': 1947,
#  'good.': 7092,
#  'Will': 3521,
#  'again': 7939,
#  'kids': 3124,
#  'weekend,': 54,
#  'your': 6415,
#  'cookies': 1936,
#  'already': 1565,
#  '(your': 4,
#  'Triple': 17,
#  'Chocolates).': 1,
#  "We're": 119,
#  'addicted': 63,
#  'jam': 430,
#  '--': 1640,
#  "it's": 4846,
#  'tend': 205,
#  'vinegar-phobic': 1,
#  'half;': 9,
#  'adore': 101,
#  'black': 1611,
#  'pepper,': 929,
#  'increase': 507,
#  'half.': 578,
#  'Also,': 1614,
#  'once': 1547,
#  'strawberries': 539,
#  'cook': 4215,
#  'down,': 140,
#  'masher': 37,
#  'break': 188,
#  'them': 19698,
#  'consistency.': 290,
#  'pepper': 4411,
#  'kick': 525,
#  'fun,': 59,
#  'English': 151,
#  'muffins,': 161,
#  'peanut': 1356,
#  'butter': 5578,
#  '&': 9666,
#  'jelly': 299,
#  'sandwiches': 473,
#  '(made': 54,
#  'wheat': 1778,
#  'bread.)': 3,
#  'wish': 832,
#  'canning': 142,
#  'store': 1249,
#  'shelf': 48,
#  'it!': 4414,
#  'started': 876,
#  'yesterday': 436,
#  'keep': 2163,
#  'up.': 1456,
#  'back': 3474,
#  'coffee': 976,
#  'figured': 251,
#  'might': 2835,
#  'along': 1573,
#  'benefits.': 13,
#  'OK,': 122,
#  'NEVER': 136,
#  'buy': 1174,
#  'jarred': 130,
#  'terrific!': 131,
#  'early': 259,
#  'day,': 352,
#  'later!': 33,
#  'pizza,': 66,
#  'freezer.': 286,
#  'cant': 183,
#  'wait.': 64,
#  'hint': 419,
#  'spice': 1363,
#  'red': 4425,
#  'omitted': 1607,
#  'flakes': 754,
#  'small': 3042,
#  'delicious.': 3791,
#  'again,': 2055,
#  'tenderness': 27,
#  'rub': 357,
#  'right.': 554,
#  'cold,': 101,
#  'yogurt': 962,
#  'whipped': 834,
#  'in,': 275,
#  'or': 12025,
#  'top.': 1395,
#  'cumin,': 184,
#  'curry,': 57,
#  'cinnamon': 2086,
#  'try': 8940,
#  'Chinese': 203,
#  '5.': 162,
#  "can't": 3023,
#  'resist': 98,
#  'splash': 304,
#  'too!': 1362,
#  '"bake"': 5,
#  'squash': 549,
#  'microwave': 831,
#  '8': 1714,
#  'minute': 545,
#  'blasts': 1,
#  'peel': 343,
#  'when': 9494,
#  'cool,': 89,
#  'freeze': 792,
#  'flesh.': 7,
#  'Carrots': 32,
#  'eaten': 749,
#  'right': 3564,
#  'highly': 529,
#  'recommend': 1542,
#  'these': 14421,
#  'delicious,': 1066,
#  'yet': 1088,
#  'treats!': 27,
#  'plastic': 293,
#  'popsicle': 9,
#  'molds': 10,
#  'store.': 241,
#  'halved': 1285,
#  '16': 341,
#  'popsicles.': 5,
#  'They': 6003,
#  'adults': 195,
#  'gone': 759,
#  'crazy': 379,
#  'eating': 2033,
#  'And': 2643,
#  'since': 4614,
#  "they're": 440,
#  'them!': 836,
#  'Barb': 35,
#  'become': 734,
#  'favorite!': 219,
#  'good,': 3032,
#  'modifications': 131,
#  '(and': 1002,
#  'laziness).': 1,
#  'semi': 81,
#  'breasts,': 185,
#  'browned': 670,
#  'them,': 1127,
#  'stock': 855,
#  'rest': 1884,
#  'through': 1259,
#  'simmer.': 28,
#  'omit': 595,
#  'avoid': 195,
#  'sugary-ness': 1,
#  'commented': 144,
#  'PERFECT.': 36,
#  'As': 1603,
#  'couscous': 179,
#  'anything,': 94,
#  'cold': 1240,
#  'broth': 1956,
#  'soak': 317,
#  'wait': 2103,
#  'breasts': 981,
#  'cook.': 332,
#  'margarine': 313,
#  'garlic-buttery': 1,
#  'certainly': 920,
#  'disappoint).': 1,
#  '#289161.': 1,
#  'Miraklegirl!': 4,
#  'fantastic!': 787,
#  'soft': 1275,
#  'chewy': 397,
#  'loveddd': 1,
#  'friends.': 198,
#  'chopped': 3132,
#  'mars': 2,
#  'bar': 219,
#  'chocolate': 4610,
#  'chips': 1692,
#  'worked': 3075,
#  'charm': 25,
#  'definitely': 6270,
#  'THANKS': 131,
#  'Christmas': 1345,
#  'party!': 72,
#  'treat!': 353,
#  'dressing': 2160,
#  'lot.': 377,
#  'sesame': 650,
#  'seeds': 808,
#  'lamb': 384,
#  'marinaded': 65,
#  'spices.': 384,
#  'posting': 4355,
#  'simply': 738,
#  'WONDERFUL!': 103,
#  'any': 6235,
#  'salt,': 1022,
#  'substitution': 119,
#  "necessity..didn't": 1,
#  'hash': 168,
#  'browns,': 19,
#  'potatoes.': 1015,
#  'About': 76,
#  'half': 7895,
#  'peeked': 5,
#  'browning': 302,
#  'bottom': 1067,
#  'potatoes': 3794,
#  "weren't": 511,
#  'cooking.': 737,
#  'needed': 2634,
#  'water.': 915,
#  'DUH!': 1,
#  'remember': 574,
#  'how': 5264,
#  'added,': 81,
#  "I'll": 5462,
#  'redo': 7,
#  'browns': 104,
#  'die': 409,
#  'for....': 2,
#  'truly!': 1,
#  'good..': 26,
#  'it..': 66,
#  'give': 3294,
#  '3.5': 93,
#  'stars.': 702,
#  'okay': 242,
#  'again.<br/><br/>I': 2,
#  'drumsticks': 59,
#  'wings': 426,
#  'grocery': 438,
#  'low': 2408,
#  'sodium': 453,
#  'soy': 1154,
#  'sauce.': 3065,
#  'forget': 241,
#  'marinade': 1074,
#  'chicken.': 1207,
#  'know': 3493,
#  'affected': 64,
#  'thicker.': 87,
#  'barbecue': 199,
#  'move': 69,
#  'fluid.': 7,
#  'thicken': 702,
#  'starch': 190,
#  'flour.': 781,
#  'stated': 531,
#  ':-)': 711,
#  'breakfast!': 175,
#  'mom': 793,
#  'Northern': 39,
#  'Ireland': 14,
#  'introduced': 39,
#  'Marmite': 9,
#  'age': 38,
#  'rye': 150,
#  'marmite': 8,
#  'dip': 1015,
#  'eggs.': 411,
#  'you!': 1511,
#  "Paula's": 14,
#  'Peach': 20,
#  'Dump': 9,
#  'Cake': 200,
#  '#125391': 1,
#  '(only': 110,
#  '4)': 32,
#  'forward': 785,
#  'her': 1377,
#  'call': 572,
#  'future.': 290,
#  'hand': 1526,
#  'dessert': 1009,
#  "'fix'": 2,
#  'table': 454,
#  'short': 442,
#  'notice.': 16,
#  'Wow!': 692,
#  'What': 2635,
#  'amazing': 896,
#  'stuff!': 204,
#  'Hokey': 4,
#  'Pokey': 5,
#  'ice-cream,': 6,
#  'this.': 2919,
#  'shocked': 59,
#  'complete': 234,
#  'colour': 106,
#  'after': 5686,
#  'stirring': 212,
#  'baking': 3091,
#  'soda': 304,
#  'through.': 300,
#  'quick.': 197,
#  'burned': 183,
#  'ours': 252,
#  'difficult': 371,
#  'spread': 1079,
#  'flat': 296,
#  'pan,': 649,
#  'first': 6061,
#  'go.': 188,
#  "what's": 98,
#  'come!': 38,
#  'manual': 7,
#  'method': 626,
#  'directions': 1514,
#  'follow': 832,
#  'produced': 149,
#  'results.': 585,
#  'light': 2557,
#  "za'atar": 11,
#  'topping.': 470,
#  'keeper!': 1357,
#  'Best': 641,
#  '2011': 181,
#  'event,': 33,
#  'recommended': 325,
#  'awalde': 7,
#  'sorry.': 82,
#  "wasn't": 2828,
#  'stretch.': 6,
#  'There': 1164,
#  'something': 3790,
#  'missing': 501,
#  'turn': 1175,
#  'amazing.': 617,
#  'turmeric': 68,
#  'strange': 126,
#  'color': 572,
#  'unappealing.': 7,
#  'smelled': 705,
#  'carne': 7,
#  'asada': 5,
#  'maybe': 2146,
#  'expecting.': 53,
#  'cooked': 6320,
#  'delightful': 259,
#  'while': 3130,
#  'grilling': 225,
#  'meet': 53,
#  'expectations': 42,
#  'served.': 69,
#  'watching': 228,
#  'think': 10741,
#  'tweak': 194,
#  'sure': 5335,
#  'is.': 649,
#  'Did': 470,
#  'Bergy!!': 11,
#  'microwaved': 176,
#  'spuds,': 5,
#  'onions,': 735,
#  'later': 496,
#  'night.': 701,
#  'onion': 3958,
#  'each': 2204,
#  'their': 1558,
#  'flavours': 430,
#  'come': 1545,
#  'distinctly.': 1,
#  'veggie': 655,
#  'dish.': 2720,
#  'Lovely!': 31,
#  'beautiful': 760,
#  'Thanksgiving': 638,
#  'morning.': 393,
#  'With': 679,
#  'link': 42,
#  'sliced': 2058,
#  'fruit': 1049,
#  'enjoy': 1321,
#  'visiting': 112,
#  'grands': 5,
#  'breakfast.': 485,
#  'Kittencal.': 83,
#  'teach': 25,
#  'high': 1257,
#  'school': 333,
#  'foods': 180,
#  'class': 97,
#  'studying': 8,
#  'legumes.': 2,
#  'topping': 1361,
#  'sour': 2563,
#  'cream,': 790,
#  'cheese,': 1369,
#  'Tobasco': 19,
#  'tortilla': 508,
#  'chips.': 644,
#  'While': 430,
#  'making,': 33,
#  'students': 37,
#  'look': 1527,
#  'Not': 1868,
#  'single': 364,
#  'student': 38,
#  '25': 458,
#  'disliked': 19,
#  'students.': 8,
#  'starting': 247,
#  'hour': 1180,
#  'period': 41,
#  'reheating': 45,
#  'day.': 1234,
#  'Many': 188,
#  'requested': 363,
#  'second': 1653,
#  'copy': 147,
#  'take': 2302,
#  'home!': 99,
#  'Great': 5706,
#  'job!': 35,
#  'definately': 1073,
#  'lemon': 3808,
#  'zest': 575,
#  'devine': 17,
#  'reheat': 135,
#  'oven': 3333,
#  'crunchiness!': 2,
#  ...}

# %%
# %time get_word_reviews_count1(reviews)
# Out:
# CPU times: user 3.12 s, sys: 6.09 ms, total: 3.13 s
# Wall time: 3.16 s
# {'Last': 100,
#  'week': 804,
#  'whole': 5630,
#  'sides': 313,
#  'of': 109040,
#  'frozen': 2648,
#  'salmon': 729,
#  'fillet': 60,
#  'was': 88793,
#  'on': 34590,
#  'sale': 149,
#  'in': 61551,
#  'my': 44166,
#  'local': 561,
#  'supermarket,': 10,
#  'so': 46106,
#  'I': 288141,
#  'bought': 1369,
#  'tons': 161,
#  '(okay,': 5,
#  'only': 13967,
#  '3,': 48,
#  'but': 42528,
#  'total': 381,
#  'weight': 160,
#  'over': 9066,
#  '10': 2305,
#  'pounds).': 3,
#  'This': 39937,
#  'recipe': 41128,
#  'is': 55083,
#  'perfect': 4400,
#  'for': 121248,
#  'fillet,': 14,
#  'even': 7881,
#  'though': 2315,
#  'it': 111224,
#  'calls': 520,
#  'steaks.': 96,
#  'cut': 6689,
#  'up': 13585,
#  'the': 266099,
#  'into': 7035,
#  'individual': 314,
#  'portions': 156,
#  'and': 217925,
#  'followed': 4861,
#  'instructions': 731,
#  'exactly.': 578,
#  "I'm": 7227,
#  'one': 15090,
#  'those': 2287,
#  'food': 2416,
#  'combining': 74,
#  'diets,': 5,
#  'left': 4691,
#  'out': 23647,
#  'white': 3426,
#  'wine': 1258,
#  'added': 21723,
#  'just': 24955,
#  'a': 166160,
#  'dash': 532,
#  'vinegar': 1273,
#  'instead': 10397,
#  '(just': 275,
#  'little': 16323,
#  'bit,': 316,
#  'not': 22914,
#  'enough': 4443,
#  'to': 131496,
#  'change': 4147,
#  'taste': 8037,
#  'dish).': 20,
#  'Super': 847,
#  'yummy,': 367,
#  'leftovers': 1498,
#  'lunch': 1594,
#  'today': 1035,
#  '(lucky': 3,
#  'me)!': 5,
#  'So': 4382,
#  'simple': 3952,
#  'tasty!': 1016,
#  'used': 44870,
#  'yellow': 782,
#  'capsicum': 45,
#  'place': 2012,
#  'green': 4472,
#  'because': 11394,
#  "that's": 1564,
#  'what': 7467,
#  'had': 26366,
#  'hand.': 1450,
#  'came': 5263,
#  'together': 3268,
#  'fast.': 181,
#  'Perfect': 764,
#  'meal': 1893,
#  'if': 7333,
#  'you': 24491,
#  "don't": 6185,
#  'have': 35191,
#  'lot': 3187,
#  'time.': 4086,
#  'Easy,': 294,
#  'healthy': 1282,
#  'tasty.': 2019,
#  'Thanks': 27943,
#  'Stardustannie!': 4,
#  'Made': 13273,
#  'PAC': 1488,
#  'Fall': 737,
#  '2007.': 89,
#  'Very': 8812,
#  'nice': 8169,
#  'breakfast': 1399,
#  'HH,': 1,
#  'easy': 17234,
#  'make': 32132,
#  'yummy': 2113,
#  'with': 58387,
#  'fresh': 7673,
#  'hot': 3582,
#  'coffe.': 2,
#  'Instead': 876,
#  'toast': 449,
#  'served': 6450,
#  '#97694': 1,
#  'by': 6596,
#  'Paula': 124,
#  'G': 13,
#  'that': 36991,
#  'made': 38102,
#  'earlier': 167,
#  'turned': 6372,
#  'great.': 3751,
#  'will': 23997,
#  'be': 25033,
#  'regular': 2988,
#  'our': 6879,
#  'house': 1247,
#  '-': 12026,
#  'DH': 3818,
#  'loved': 13758,
#  'them.': 3711,
#  'These': 8459,
#  'are': 15522,
#  'favorite': 2588,
#  'holidays': 123,
#  'children': 356,
#  'We': 12823,
#  'also': 14471,
#  'use': 16908,
#  'Rolo': 6,
#  'candies': 59,
#  'kisses.': 15,
#  'Excellent': 1564,
#  'soup!': 458,
#  'The': 26264,
#  'tomato': 2136,
#  'flavor': 7691,
#  'this': 87098,
#  'freezer': 875,
#  'tag': 808,
#  'soup': 4442,
#  'froze': 645,
#  'beautifully.': 316,
#  'prepared': 935,
#  'as': 35504,
#  'directed': 720,
#  'then': 8443,
#  'allowed': 225,
#  'cool': 953,
#  'container.': 47,
#  'thawed': 211,
#  'fridge': 922,
#  'reheated': 223,
#  'stovetop.': 38,
#  'Worked': 252,
#  'perfectly!': 161,
#  'forgot': 1290,
#  'add': 12993,
#  'skim': 409,
#  'milk': 3766,
#  'still': 6694,
#  'tasted': 4122,
#  'pretty': 3499,
#  'good!': 3934,
#  'Dancer!': 17,
#  'dinner': 3885,
#  'excellent,': 187,
#  'finally': 513,
#  'found': 5068,
#  'tuna': 488,
#  'casserole': 799,
#  'we': 12853,
#  'enjoy,': 11,
#  'thanks.': 130,
#  'When': 1663,
#  'snapped': 9,
#  'picture,': 61,
#  'review': 1143,
#  'recipe.': 14557,
#  'toasted': 775,
#  'pecans': 624,
#  'dish,': 803,
#  'at': 15363,
#  'party': 1244,
#  'Prime': 23,
#  'Rib.': 4,
#  'Ten': 17,
#  'stars': 2079,
#  'Lennie': 31,
#  '!!': 352,
#  'good': 16119,
#  'combination': 1801,
#  'flavors': 2214,
#  'reduce': 910,
#  'rice': 3667,
#  'cilantro': 732,
#  'next': 10083,
#  'time,': 2236,
#  'thanks': 3267,
#  'sharing': 6200,
#  'hon!...Kitten': 9,
#  'Oh': 1360,
#  'Bergy!': 64,
#  'wonderful': 5686,
#  'cakes': 433,
#  'awesome.': 557,
#  'Fast': 84,
#  'put': 8579,
#  'together.': 1467,
#  'get': 6754,
#  'fish': 1130,
#  'where': 971,
#  'live': 435,
#  '(yuck).': 5,
#  'am': 6193,
#  'tired': 147,
#  'trying': 1847,
#  'new': 2765,
#  'recipes': 2819,
#  'help': 762,
#  'lack': 174,
#  'quality.': 62,
#  'But': 2644,
#  'recipe,': 5134,
#  'problem.': 198,
#  'did': 17362,
#  '3': 4487,
#  'cloves': 900,
#  'garlic,': 1030,
#  'seasoned': 776,
#  'bread': 5904,
#  'crumbs': 801,
#  'Smash': 3,
#  'Seasoning(318441).': 1,
#  'It': 19705,
#  'has': 4861,
#  'no': 5865,
#  'salt!': 29,
#  'tartar': 77,
#  'sauce': 11432,
#  'go': 3694,
#  '(56860).': 1,
#  'Thank': 10267,
#  'great': 19179,
#  'recipe!': 8613,
#  'very': 25695,
#  'moist': 2458,
#  'cornbread,': 47,
#  'two': 4466,
#  'days': 723,
#  'later.': 245,
#  'less': 3181,
#  'sugar': 6626,
#  'honey,': 203,
#  'farm': 56,
#  'butter...and': 3,
#  'corn,': 222,
#  'about': 12814,
#  '2': 8277,
#  'ears.': 5,
#  'Served': 2024,
#  'ribs': 1203,
#  'grill,': 124,
#  "I've": 5612,
#  'been': 5787,
#  'making': 11032,
#  'past': 418,
#  'several': 1715,
#  'years.': 466,
#  "It's": 2897,
#  'always': 4171,
#  'extremely': 599,
#  'easy!': 939,
#  'posting!': 2507,
#  'generic': 30,
#  'sweetened': 239,
#  'condensed': 231,
#  'works': 748,
#  'well,': 783,
#  'tastes': 2272,
#  'costs': 17,
#  '(I': 2379,
#  'usually': 1911,
#  'Wal-Mart': 3,
#  'brand).': 9,
#  'Exceptional': 7,
#  'delicious': 5732,
#  'make.': 3070,
#  'really': 19407,
#  'liked': 5539,
#  'weekday': 69,
#  'leftover': 1716,
#  'rice.': 1119,
#  'looking': 3050,
#  'different': 3538,
#  'ways': 353,
#  'ground': 2468,
#  'beef.': 355,
#  'love': 9530,
#  'sandwich!!': 12,
#  'alot': 435,
#  'sooo': 594,
#  'Lite': 22,
#  'brown': 3477,
#  'mustard': 1084,
#  'horse': 4,
#  'relish': 160,
#  'some': 20757,
#  'olives': 583,
#  "on's.": 1,
#  'Next': 3562,
#  'time': 17505,
#  'balsamic': 483,
#  'dressing...it': 2,
#  'mind.': 77,
#  ':)': 5385,
#  'cbreezie': 1,
#  'make,': 1288,
#  'affordable': 26,
#  'addicting.': 30,
#  'Our': 372,
#  'household': 66,
#  'it.': 12186,
#  'Blessings': 7,
#  'chef': 295,
#  'sharing.': 2200,
#  'never': 4979,
#  'apple': 1442,
#  'orange': 1633,
#  'juice': 2768,
#  'makes': 3301,
#  'all': 15505,
#  'difference': 674,
#  'texture': 2318,
#  'bread.': 1218,
#  'wonderful!!': 110,
#  'You': 2333,
#  'were': 20719,
#  'delicious!': 3387,
#  'grated': 944,
#  'bit': 9947,
#  'cheddar': 1382,
#  'cheese': 8220,
#  'top': 4345,
#  '5': 4296,
#  'minutes': 5016,
#  'before': 6922,
#  'they': 16874,
#  'done,': 239,
#  'seasoning': 2026,
#  'perfect.': 2056,
#  'best': 4552,
#  'pizza': 956,
#  'dough': 2740,
#  'made!': 192,
#  'Other': 594,
#  'tried': 4438,
#  'machine': 480,
#  'way': 6710,
#  'too': 10538,
#  'sticky.': 83,
#  'Leaving': 11,
#  'msg': 19,
#  'fine.': 971,
#  'divide': 60,
#  'half,': 411,
#  'knead': 90,
#  'floured': 83,
#  'surface': 69,
#  'few': 4898,
#  'times,': 290,
#  'stretch': 74,
#  'cirle.': 1,
#  'like': 20175,
#  'bake': 1806,
#  'cast-iron': 19,
#  'skillet-': 1,
#  'brush': 161,
#  'pan': 3627,
#  'olive': 2059,
#  'oil': 3796,
#  'sprinkle': 635,
#  'corn': 2176,
#  'meal.': 1639,
#  'crust': 1662,
#  '7': 705,
#  '10-15': 75,
#  'lowest': 28,
#  'rack': 265,
#  'oven.': 1073,
#  'saw': 746,
#  'Giada': 8,
#  'Today': 109,
#  'show': 174,
#  'last': 4502,
#  'month': 271,
#  'wanted': 2689,
#  'compare': 104,
#  'family': 7202,
#  'being': 1855,
#  'Marsala': 25,
#  'dry': 2151,
#  'red,': 78,
#  'chicken/turkey': 3,
#  'sausage,': 225,
#  'cutting': 557,
#  'sausages': 113,
#  'finishing': 127,
#  'cooking': 4205,
#  'stove': 565,
#  'My': 14586,
#  'traditionally': 25,
#  'serves': 152,
#  'sausage': 1117,
#  'peppers': 1411,
#  'polenta...this': 1,
#  'compared': 122,
#  'well': 5171,
#  'probably': 2651,
#  'calories': 377,
#  'heats': 11,
#  'kitchen': 520,
#  'summertime!': 2,
#  'meatloaf,': 47,
#  'took': 3831,
#  'reviewers': 587,
#  'suggestion': 525,
#  'another': 4781,
#  'crock': 1034,
#  'pot': 1978,
#  'meatloaf': 395,
#  '(#99616)': 1,
#  'it,': 3814,
#  'sauce,': 1640,
#  'meatloaf.': 109,
#  'sweet': 4940,
#  'tangy': 290,
#  'wonder': 263,
#  'addition.': 281,
#  'again.': 7485,
#  'deliciously': 87,
#  'simple.': 295,
#  'can': 9516,
#  'literally': 148,
#  'thrown': 103,
#  'soups': 203,
#  'i': 7828,
#  'ever': 3857,
#  'had.': 897,
#  'uncomplicated': 6,
#  'taste.': 2088,
#  ',': 715,
#  'from': 12806,
#  'appealed': 20,
#  'me': 7276,
#  'simplicity': 162,
#  'quick': 4069,
#  'could': 6288,
#  'made.': 711,
#  'both': 2698,
#  'flavor.': 3964,
#  'anything': 1423,
#  'see': 2246,
#  'can;': 1,
#  'more': 16845,
#  'substance': 14,
#  'nothing': 719,
#  '(thankfully)': 3,
#  'rustic': 43,
#  'roasted': 1256,
#  'balance': 423,
#  'other': 7019,
#  'ingredients.': 1100,
#  'paul': 2,
#  'newman': 1,
#  'marinara': 109,
#  '1/3': 780,
#  'cup': 7165,
#  'let': 2910,
#  'simmer': 398,
#  'out.': 1250,
#  'would': 16602,
#  'definitly': 60,
#  'much': 12368,
#  'plus': 779,
#  'tea!': 46,
#  'aroma': 300,
#  'tea': 535,
#  'steeping': 10,
#  'five': 664,
#  'minutes,': 843,
#  'wonderful!': 1125,
#  'large': 2093,
#  'glass': 571,
#  'ice': 1502,
#  'enjoyed!': 71,
#  'Good': 1356,
#  'marinade.': 220,
#  'Jack': 169,
#  'Daniels': 23,
#  'exactly': 3584,
#  'except': 2035,
#  "didn't": 14049,
#  'marinate': 353,
#  'quite': 3821,
#  'long.': 228,
#  'hours.': 885,
#  'grilled': 1248,
#  'counter': 138,
#  'grill': 812,
#  'everyone': 2532,
#  'enjoyed': 6746,
#  'Even': 1386,
#  'DH,': 123,
#  'who': 3069,
#  "doesn't": 1810,
#  'beef': 2514,
#  'dressed': 64,
#  'up,': 513,
#  'said': 3122,
#  'Almost': 108,
#  'teriyaki': 96,
#  'baked': 4138,
#  'potato': 1755,
#  'asparagus.': 144,
#  'posting.': 2316,
#  'Fantastic': 367,
#  'earning': 2,
#  'raves': 111,
#  'table.': 207,
#  'Thanks,': 1423,
#  'homegirl!': 5,
#  'comforting.': 50,
#  'low-sodium,': 1,
#  'low-fat': 296,
#  'chicken': 11333,
#  'stock.': 172,
#  'butter.': 965,
#  'dried': 2248,
#  'parsley.': 205,
#  'do': 6861,
#  'than': 10334,
#  'an': 10558,
#  'hour,': 174,
#  'Me': 68,
#  'course.': 94,
#  'Breezermom': 3,
#  'Market': 162,
#  'game': 469,
#  'Easy': 1947,
#  'good.': 7092,
#  'Will': 3521,
#  'again': 7939,
#  'kids': 3124,
#  'weekend,': 54,
#  'your': 6415,
#  'cookies': 1936,
#  'already': 1565,
#  '(your': 4,
#  'Triple': 17,
#  'Chocolates).': 1,
#  "We're": 119,
#  'addicted': 63,
#  'jam': 430,
#  '--': 1640,
#  "it's": 4846,
#  'tend': 205,
#  'vinegar-phobic': 1,
#  'half;': 9,
#  'adore': 101,
#  'black': 1611,
#  'pepper,': 929,
#  'increase': 507,
#  'half.': 578,
#  'Also,': 1614,
#  'once': 1547,
#  'strawberries': 539,
#  'cook': 4215,
#  'down,': 140,
#  'masher': 37,
#  'break': 188,
#  'them': 19698,
#  'consistency.': 290,
#  'pepper': 4411,
#  'kick': 525,
#  'fun,': 59,
#  'English': 151,
#  'muffins,': 161,
#  'peanut': 1356,
#  'butter': 5578,
#  '&': 9666,
#  'jelly': 299,
#  'sandwiches': 473,
#  '(made': 54,
#  'wheat': 1778,
#  'bread.)': 3,
#  'wish': 832,
#  'canning': 142,
#  'store': 1249,
#  'shelf': 48,
#  'it!': 4414,
#  'started': 876,
#  'yesterday': 436,
#  'keep': 2163,
#  'up.': 1456,
#  'back': 3474,
#  'coffee': 976,
#  'figured': 251,
#  'might': 2835,
#  'along': 1573,
#  'benefits.': 13,
#  'OK,': 122,
#  'NEVER': 136,
#  'buy': 1174,
#  'jarred': 130,
#  'terrific!': 131,
#  'early': 259,
#  'day,': 352,
#  'later!': 33,
#  'pizza,': 66,
#  'freezer.': 286,
#  'cant': 183,
#  'wait.': 64,
#  'hint': 419,
#  'spice': 1363,
#  'red': 4425,
#  'omitted': 1607,
#  'flakes': 754,
#  'small': 3042,
#  'delicious.': 3791,
#  'again,': 2055,
#  'tenderness': 27,
#  'rub': 357,
#  'right.': 554,
#  'cold,': 101,
#  'yogurt': 962,
#  'whipped': 834,
#  'in,': 275,
#  'or': 12025,
#  'top.': 1395,
#  'cumin,': 184,
#  'curry,': 57,
#  'cinnamon': 2086,
#  'try': 8940,
#  'Chinese': 203,
#  '5.': 162,
#  "can't": 3023,
#  'resist': 98,
#  'splash': 304,
#  'too!': 1362,
#  '"bake"': 5,
#  'squash': 549,
#  'microwave': 831,
#  '8': 1714,
#  'minute': 545,
#  'blasts': 1,
#  'peel': 343,
#  'when': 9494,
#  'cool,': 89,
#  'freeze': 792,
#  'flesh.': 7,
#  'Carrots': 32,
#  'eaten': 749,
#  'right': 3564,
#  'highly': 529,
#  'recommend': 1542,
#  'these': 14421,
#  'delicious,': 1066,
#  'yet': 1088,
#  'treats!': 27,
#  'plastic': 293,
#  'popsicle': 9,
#  'molds': 10,
#  'store.': 241,
#  'halved': 1285,
#  '16': 341,
#  'popsicles.': 5,
#  'They': 6003,
#  'adults': 195,
#  'gone': 759,
#  'crazy': 379,
#  'eating': 2033,
#  'And': 2643,
#  'since': 4614,
#  "they're": 440,
#  'them!': 836,
#  'Barb': 35,
#  'become': 734,
#  'favorite!': 219,
#  'good,': 3032,
#  'modifications': 131,
#  '(and': 1002,
#  'laziness).': 1,
#  'semi': 81,
#  'breasts,': 185,
#  'browned': 670,
#  'them,': 1127,
#  'stock': 855,
#  'rest': 1884,
#  'through': 1259,
#  'simmer.': 28,
#  'omit': 595,
#  'avoid': 195,
#  'sugary-ness': 1,
#  'commented': 144,
#  'PERFECT.': 36,
#  'As': 1603,
#  'couscous': 179,
#  'anything,': 94,
#  'cold': 1240,
#  'broth': 1956,
#  'soak': 317,
#  'wait': 2103,
#  'breasts': 981,
#  'cook.': 332,
#  'margarine': 313,
#  'garlic-buttery': 1,
#  'certainly': 920,
#  'disappoint).': 1,
#  '#289161.': 1,
#  'Miraklegirl!': 4,
#  'fantastic!': 787,
#  'soft': 1275,
#  'chewy': 397,
#  'loveddd': 1,
#  'friends.': 198,
#  'chopped': 3132,
#  'mars': 2,
#  'bar': 219,
#  'chocolate': 4610,
#  'chips': 1692,
#  'worked': 3075,
#  'charm': 25,
#  'definitely': 6270,
#  'THANKS': 131,
#  'Christmas': 1345,
#  'party!': 72,
#  'treat!': 353,
#  'dressing': 2160,
#  'lot.': 377,
#  'sesame': 650,
#  'seeds': 808,
#  'lamb': 384,
#  'marinaded': 65,
#  'spices.': 384,
#  'posting': 4355,
#  'simply': 738,
#  'WONDERFUL!': 103,
#  'any': 6235,
#  'salt,': 1022,
#  'substitution': 119,
#  "necessity..didn't": 1,
#  'hash': 168,
#  'browns,': 19,
#  'potatoes.': 1015,
#  'About': 76,
#  'half': 7895,
#  'peeked': 5,
#  'browning': 302,
#  'bottom': 1067,
#  'potatoes': 3794,
#  "weren't": 511,
#  'cooking.': 737,
#  'needed': 2634,
#  'water.': 915,
#  'DUH!': 1,
#  'remember': 574,
#  'how': 5264,
#  'added,': 81,
#  "I'll": 5462,
#  'redo': 7,
#  'browns': 104,
#  'die': 409,
#  'for....': 2,
#  'truly!': 1,
#  'good..': 26,
#  'it..': 66,
#  'give': 3294,
#  '3.5': 93,
#  'stars.': 702,
#  'okay': 242,
#  'again.<br/><br/>I': 2,
#  'drumsticks': 59,
#  'wings': 426,
#  'grocery': 438,
#  'low': 2408,
#  'sodium': 453,
#  'soy': 1154,
#  'sauce.': 3065,
#  'forget': 241,
#  'marinade': 1074,
#  'chicken.': 1207,
#  'know': 3493,
#  'affected': 64,
#  'thicker.': 87,
#  'barbecue': 199,
#  'move': 69,
#  'fluid.': 7,
#  'thicken': 702,
#  'starch': 190,
#  'flour.': 781,
#  'stated': 531,
#  ':-)': 711,
#  'breakfast!': 175,
#  'mom': 793,
#  'Northern': 39,
#  'Ireland': 14,
#  'introduced': 39,
#  'Marmite': 9,
#  'age': 38,
#  'rye': 150,
#  'marmite': 8,
#  'dip': 1015,
#  'eggs.': 411,
#  'you!': 1511,
#  "Paula's": 14,
#  'Peach': 20,
#  'Dump': 9,
#  'Cake': 200,
#  '#125391': 1,
#  '(only': 110,
#  '4)': 32,
#  'forward': 785,
#  'her': 1377,
#  'call': 572,
#  'future.': 290,
#  'hand': 1526,
#  'dessert': 1009,
#  "'fix'": 2,
#  'table': 454,
#  'short': 442,
#  'notice.': 16,
#  'Wow!': 692,
#  'What': 2635,
#  'amazing': 896,
#  'stuff!': 204,
#  'Hokey': 4,
#  'Pokey': 5,
#  'ice-cream,': 6,
#  'this.': 2919,
#  'shocked': 59,
#  'complete': 234,
#  'colour': 106,
#  'after': 5686,
#  'stirring': 212,
#  'baking': 3091,
#  'soda': 304,
#  'through.': 300,
#  'quick.': 197,
#  'burned': 183,
#  'ours': 252,
#  'difficult': 371,
#  'spread': 1079,
#  'flat': 296,
#  'pan,': 649,
#  'first': 6061,
#  'go.': 188,
#  "what's": 98,
#  'come!': 38,
#  'manual': 7,
#  'method': 626,
#  'directions': 1514,
#  'follow': 832,
#  'produced': 149,
#  'results.': 585,
#  'light': 2557,
#  "za'atar": 11,
#  'topping.': 470,
#  'keeper!': 1357,
#  'Best': 641,
#  '2011': 181,
#  'event,': 33,
#  'recommended': 325,
#  'awalde': 7,
#  'sorry.': 82,
#  "wasn't": 2828,
#  'stretch.': 6,
#  'There': 1164,
#  'something': 3790,
#  'missing': 501,
#  'turn': 1175,
#  'amazing.': 617,
#  'turmeric': 68,
#  'strange': 126,
#  'color': 572,
#  'unappealing.': 7,
#  'smelled': 705,
#  'carne': 7,
#  'asada': 5,
#  'maybe': 2146,
#  'expecting.': 53,
#  'cooked': 6320,
#  'delightful': 259,
#  'while': 3130,
#  'grilling': 225,
#  'meet': 53,
#  'expectations': 42,
#  'served.': 69,
#  'watching': 228,
#  'think': 10741,
#  'tweak': 194,
#  'sure': 5335,
#  'is.': 649,
#  'Did': 470,
#  'Bergy!!': 11,
#  'microwaved': 176,
#  'spuds,': 5,
#  'onions,': 735,
#  'later': 496,
#  'night.': 701,
#  'onion': 3958,
#  'each': 2204,
#  'their': 1558,
#  'flavours': 430,
#  'come': 1545,
#  'distinctly.': 1,
#  'veggie': 655,
#  'dish.': 2720,
#  'Lovely!': 31,
#  'beautiful': 760,
#  'Thanksgiving': 638,
#  'morning.': 393,
#  'With': 679,
#  'link': 42,
#  'sliced': 2058,
#  'fruit': 1049,
#  'enjoy': 1321,
#  'visiting': 112,
#  'grands': 5,
#  'breakfast.': 485,
#  'Kittencal.': 83,
#  'teach': 25,
#  'high': 1257,
#  'school': 333,
#  'foods': 180,
#  'class': 97,
#  'studying': 8,
#  'legumes.': 2,
#  'topping': 1361,
#  'sour': 2563,
#  'cream,': 790,
#  'cheese,': 1369,
#  'Tobasco': 19,
#  'tortilla': 508,
#  'chips.': 644,
#  'While': 430,
#  'making,': 33,
#  'students': 37,
#  'look': 1527,
#  'Not': 1868,
#  'single': 364,
#  'student': 38,
#  '25': 458,
#  'disliked': 19,
#  'students.': 8,
#  'starting': 247,
#  'hour': 1180,
#  'period': 41,
#  'reheating': 45,
#  'day.': 1234,
#  'Many': 188,
#  'requested': 363,
#  'second': 1653,
#  'copy': 147,
#  'take': 2302,
#  'home!': 99,
#  'Great': 5706,
#  'job!': 35,
#  'definately': 1073,
#  'lemon': 3808,
#  'zest': 575,
#  'devine': 17,
#  'reheat': 135,
#  'oven': 3333,
#  'crunchiness!': 2,
#  ...}

# %%
# %lprun -f get_word_reviews_count1 get_word_reviews_count1(reviews)

# %% [markdown]
# Timer unit: 1e-09 s
#
# Total time: 8.74462 s
# File: <ipython-input-90-5c1a8be13ef7>
# Function: get_word_reviews_count1 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def get_word_reviews_count1(df):
#      2         1       2030.0   2030.0      0.0    sl = {}
#      3    126696   68248512.0    538.7      0.8    for i in df.review:
#      4    126696   25407584.0    200.5      0.3      try:
#      5    126679  506998137.0   4002.2      5.8        words = i.split()
#      6        17       4413.0    259.6      0.0      except:
#      7        17      22353.0   1314.9      0.0        continue
#      8   6589870 1605341552.0    243.6     18.4      for j in words:
#      9   6425599 3507118858.0    545.8     40.1        if j not in sl.keys():
#     10    164271   70768984.0    430.8      0.8          sl[j] = 1
#     11                                                 else:
#     12   6425599 2960711131.0    460.8     33.9          sl[j] +=1
#     13         1        676.0    676.0      0.0    return sl

# %% [markdown]
# 4. Напишите несколько версий функции `MAPE` (см. [MAPE](https://en.wikipedia.org/wiki/Mean_absolute_percentage_error)) для расчета среднего абсолютного процентного отклонения значения рейтинга отзыва на рецепт от среднего значения рейтинга по всем отзывам для этого рецепта.
#     1. Без использования векторизованных операций и методов массивов `numpy` и без использования `numba`
#     2. Без использования векторизованных операций и методов массивов `numpy`, но с использованием `numba`
#     3. С использованием векторизованных операций и методов массивов `numpy`, но без использования `numba`
#     4. C использованием векторизованных операций и методов массивов `numpy` и `numba`
#
# Измерьте время выполнения каждой из реализаций.
#
# Замечание: удалите из выборки отзывы с нулевым рейтингом.

# %%
import numba
from numba import jit, njit

# %%
sr = reviews[reviews['rating'] != 0].rating.mean()
sr
# Out:
# 4.6611588859881055

# %%
def f1():
  m, n = 0, 0
  for i in reviews[reviews['rating'] != 0].rating:
      m += abs((i-sr)/i)
      n+=1
  return 100/n * m
f1()
# Out:
# 16.266663338761624

# %%
# %time f1()
# Out:
# CPU times: user 106 ms, sys: 0 ns, total: 106 ms
# Wall time: 107 ms
# 16.266663338761624

# %%
@jit
def f2():
  m, n = 0, 0
  for i in reviews[reviews['rating'] != 0].rating:
      m += abs((i-sr)/i)
      n+=1
  return 100/n * m

# %%
# %%time 
f2()
# Out:
# <ipython-input-116-002bef8f0864>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "f2" failed type inference due to: Untyped global name 'reviews': Cannot determine Numba type of <class 'pandas.core.frame.DataFrame'>
#
# File "<ipython-input-116-002bef8f0864>", line 4:
# def f2():
#     <source elided>
#   m, n = 0, 0
#   for i in reviews[reviews['rating'] != 0].rating:
#   ^
#
#   @jit
# <ipython-input-116-002bef8f0864>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "f2" failed type inference due to: Untyped global name 'reviews': Cannot determine Numba type of <class 'pandas.core.frame.DataFrame'>
#
# File "<ipython-input-116-002bef8f0864>", line 4:
# def f2():
#     <source elided>
#   m, n = 0, 0
#   for i in reviews[reviews['rating'] != 0].rating:
#   ^
#
#   @jit
# /usr/local/lib/python3.10/dist-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "f2" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "<ipython-input-116-002bef8f0864>", line 3:
# def f2():
#   m, n = 0, 0
#   ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /usr/local/lib/python3.10/dist-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-116-002bef8f0864>", line 3:
# def f2():
#   m, n = 0, 0
#   ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <ipython-input-116-002bef8f0864>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "f2" failed type inference due to: non-precise type pyobject
# During: typing of argument at <ipython-input-116-002bef8f0864> (4)
#
# File "<ipython-input-116-002bef8f0864>", line 4:
# def f2():
#     <source elided>
#   m, n = 0, 0
#   for i in reviews[reviews['rating'] != 0].rating:
#   ^
#
#   @jit
# /usr/local/lib/python3.10/dist-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "f2" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-116-002bef8f0864>", line 4:
# def f2():
#     <source elided>
#   m, n = 0, 0
#   for i in reviews[reviews['rating'] != 0].rating:
#   ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /usr/local/lib/python3.10/dist-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-116-002bef8f0864>", line 4:
# def f2():
#     <source elided>
#   m, n = 0, 0
#   for i in reviews[reviews['rating'] != 0].rating:
#   ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# CPU times: user 632 ms, sys: 5.8 ms, total: 638 ms
# Wall time: 646 ms
# 16.266663338761624

# %%
def f3():
  m, n = 0, 0
  for i in reviews[reviews['rating'] != 0].rating.to_numpy():
    m += abs((i-sr)/i)
    n+=1
  return 100/n * m

f3()
# Out:
# 16.266663338761624

# %%
# %time f3()
# Out:
# CPU times: user 647 ms, sys: 868 µs, total: 647 ms
# Wall time: 678 ms
# 16.266663338761624

# %%
@jit
def f4():
  m, n = 0, 0
  for i in reviews[reviews['rating'] != 0].rating.to_numpy():
    m += abs((i-sr)/i)
    n+=1
  return 100/n * m

# %%
# %time f4()
# Out:
# <ipython-input-183-3e28c5e0a1b0>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "f4" failed type inference due to: Untyped global name 'reviews': Cannot determine Numba type of <class 'pandas.core.frame.DataFrame'>
#
# File "<ipython-input-183-3e28c5e0a1b0>", line 4:
# def f4():
#     <source elided>
#   m, n = 0, 0
#   for i in reviews[reviews['rating'] != 0].rating.to_numpy():
#   ^
#
#   @jit
# <ipython-input-183-3e28c5e0a1b0>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "f4" failed type inference due to: Untyped global name 'reviews': Cannot determine Numba type of <class 'pandas.core.frame.DataFrame'>
#
# File "<ipython-input-183-3e28c5e0a1b0>", line 4:
# def f4():
#     <source elided>
#   m, n = 0, 0
#   for i in reviews[reviews['rating'] != 0].rating.to_numpy():
#   ^
#
#   @jit
# /usr/local/lib/python3.10/dist-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "f4" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "<ipython-input-183-3e28c5e0a1b0>", line 3:
# def f4():
#   m, n = 0, 0
#   ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /usr/local/lib/python3.10/dist-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-183-3e28c5e0a1b0>", line 3:
# def f4():
#   m, n = 0, 0
#   ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# CPU times: user 414 ms, sys: 1.85 ms, total: 416 ms
# Wall time: 416 ms
# 16.266663338761624

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1, 3, 4
